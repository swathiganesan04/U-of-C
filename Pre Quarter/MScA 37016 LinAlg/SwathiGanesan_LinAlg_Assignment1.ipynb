# %% [markdown]
# ### Importing libraries

# %%
import numpy as np
from scipy import linalg as la

# %% [markdown]
# ### Defining the inputs

# %%
A = np.array([[0,3,-1],
            [-1,4,-2],
            [1,3,1]]) 

B = np.array([[2,-1,2],
            [-1,0,1],
            [-1,2,2]]) 


v = np.array([2,-1,4])
u = np.array([-2,1,5])

a = -2
b = 1

# %% [markdown]
# <b>Question 1</b>
# 1) Calculate

# %% [markdown]
# ![Screenshot%202022-08-27%20at%202.50.38%20PM.png](attachment:Screenshot%202022-08-27%20at%202.50.38%20PM.png)

# %% [markdown]
# 2) Python Validation

# %%
#L1 norm of vector v
v_norm = la.norm(v,1)

#scalar multiplication v_norm * vector v
v_norm_times_v = v_norm*v

#scalar multiplicaition a * vector u
a_times_u = a*u

#sum of the entities
result = v_norm_times_v + a_times_u
print("Result :", result)
# Out:
# Result : [18. -9. 18.]

# %% [markdown]
# <br>
# <br>

# %% [markdown]
# <b>Question 2</b>
# 1) Calculate

# %% [markdown]
# ![Screenshot%202022-08-27%20at%203.40.21%20PM.png](attachment:Screenshot%202022-08-27%20at%203.40.21%20PM.png)

# %% [markdown]
# 2) Python Validation

# %%
#scalar product of vectors v and u 
v_dot_u = np.dot(v,u)

#vector norm of vector v
v_norm = la.norm(v,2)

#vector norm of vector u
u_norm = la.norm(u,2)

#cos𝜃 = v_dot_u /(v_norm*u_norm)
Cosine_Theta = v_dot_u / (v_norm*u_norm)

print('Cosine Theta : ', Cosine_Theta)
print('Angle  [rad] : ',round(np.arccos(Cosine_Theta)/np.pi,3),'pi')
# Out:
# Cosine Theta :  0.5976143046671969
# Angle  [rad] :  0.296 pi

# %% [markdown]
# <br>
# <br>

# %% [markdown]
# <b>Question 3</b>
# 1) Calculate

# %% [markdown]
# ![Screenshot%202022-08-27%20at%203.39.34%20PM.png](attachment:Screenshot%202022-08-27%20at%203.39.34%20PM.png)

# %% [markdown]
# 2) Python Validation

# %%
#dot product of matrix A and vector v
A_dot_v = A.dot(v)

#scalar multiplication of a and vector A.v
a_times_A_dot_v = a * A_dot_v

print("Result :", a_times_A_dot_v)
# Out:
# Result : [14 28 -6]

# %% [markdown]
# <br>
# <br>

# %% [markdown]
# <b>Question 4</b>
# 1) Calculate

# %% [markdown]
# ![Screenshot%202022-08-27%20at%204.15.23%20PM.png](attachment:Screenshot%202022-08-27%20at%204.15.23%20PM.png)

# %% [markdown]
# 2) Python Validation

# %%
#𝑨∙𝑩𝑇 +𝑡𝑟(𝑩)∗𝑳

#transpose of matrix B
BTrans = B.T

#dot product of matrix A and transpose of matric B
A_dot_BTrans = A.dot(BTrans)

#trace of matrix B ( sum of diagonal elements)
BTrace = B.trace()

#lower triangular matrix of matrix B
L = la.tril(B)

#trace(B) times lower triangular matrix L
BTrace_times_L = BTrace*L

#final result 
result = A_dot_BTrans + BTrace_times_L

print("Result :")
print(result,'\n')
# Out:
# Result :
# [[  3  -1   4]
#  [-14  -1   5]
#  [ -3   8  15]]
